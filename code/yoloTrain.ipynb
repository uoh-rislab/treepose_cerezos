# %% [markdown]
# Importar librerias

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.8/906.8 kB 39.2 MB/s eta 0:00:00
# ...

# %%
#Import libs
import ultralytics
import random
import os
from google.colab import drive
from matplotlib import pyplot as plt
import numpy as np
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# Montar drive y definir path del dataset

# %%
#Mount drive
drive.mount('/content/drive')

# %%
path = "/content/drive/MyDrive/Universidad/Tesis/Datasets/dataset"

# %% [markdown]
# Entrenamiento de modelos YOLOv11-pose

# %%
#Load model
model = ultralytics.YOLO('yolo11m-pose.pt')  # build a new model from YAML
#Train model
results = model.train(data=path+"/data.yaml", epochs=200, imgsz=800,fliplr=0.5,batch=16)
# Out:
# ...
# 100%|██████████| 40.5M/40.5M [00:01<00:00, 35.0MB/s]
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#Load model
model = ultralytics.YOLO('yolo11n-pose.pt')  # build a new model from YAML
#Train model
results = model.train(data=path+"/data.yaml", epochs=200, imgsz=800,fliplr=0.5,batch=16)
# Out:
# ...
# 100%|██████████| 5.97M/5.97M [00:00<00:00, 132MB/s]
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#Load model
model = ultralytics.YOLO('yolo11l-pose.pt')  # build a new model from YAML
#Train model
results = model.train(data=path+"/data.yaml", epochs=200, imgsz=600,fliplr=0.5,batch=12)
# Out:
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#Load model
model = ultralytics.YOLO('yolo11x-pose.pt')  # build a new model from YAML
#Train model
results = model.train(data=path+"/data.yaml", epochs=200, imgsz=600,fliplr=0.5,batch=4)
# Out:
# ...
# 100%|██████████| 113M/113M [00:00<00:00, 179MB/s]
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Descarga de zips con resultados

# %%
# !sudo locale-gen en_US.UTF-8
# !sudo update-locale LANG=en_US.UTF-8
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# !zip -r /content/drive/MyDrive/Universidad/Tesis/yolo11m_colabT4batch8epoch150size1024.zip /content/runs

# %%
# !sudo locale-gen en_US.UTF-8
# !sudo update-locale LANG=en_US.UTF-8
# !zip -r /content/drive/MyDrive/Universidad/Tesis/yolo11m_colabT4batch8epoch150size1024.zip /content/runs

# %%
from google.colab import files
files.download("/content/runs.zip")
